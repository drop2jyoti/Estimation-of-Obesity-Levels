# %% [markdown]
# ## Obesity Levels Based On Eating Habits and Physical Condition
#
# ### The dataset contains 2111 rows and 17 columns, with a mix of categorical and numerical variables. Here's a breakdown of the key columns:
#
# - Age, Height, Weight, FCVC, NCP, CH2O, FAF, TUE: Numerical variables
#
# - Gender, family_history_with_overweight, FAVC, CAEC, SMOKE, SCC, CALC, MTRANS, NObeyesdad: Categorical variables

# %% [markdown]
# ### Dataset
#
# •	Gender
#
# •	Age:  A person's age may affect their metabolic rate and lifestyle, influencing obesity levels.
#
# •	Height: Useful for calculating Body Mass Index (BMI), which is closely related to obesity.
#
# •	Weight: One of the most critical variables for determining obesity.
#
# •	Family History with Overweight: Whether a person has a genetic predisposition to being overweight or obese, which can significantly impact obesity risk.
#
# •	Frequent Consumption of High-Calorie Food (FAVC): This reflects dietary habits, particularly the consumption of high-calorie foods, which is a known risk factor for obesity.
#
# •	Frequency of Consumption of Vegetables (FCVC): A higher intake of vegetables is typically associated with a healthier diet and lower risk of obesity.
#
# •	Number of Meals (NCP): The number of meals consumed daily can impact weight gain, especially if portion sizes are not controlled.
#
# •	Consumption of Food Between Meals (CAEC): Eating snacks or meals outside of regular eating hours can contribute to weight gain.
#
# •	Smoking Habit (SMOKE): Smoking status can influence metabolism and overall health, affecting obesity.
#
# •	Water Intake (CH2O): Adequate water intake can aid in digestion and prevent overeating, indirectly influencing weight management.
#
# •	Calories Consumed (CALC): Regular or frequent alcohol consumption adds extra calories, contributing to weight gain.
#
# •	Physical Activity Frequency (FAF): Frequency of physical activity is a key factor in energy expenditure and weight control.
#
# •	Time Spent Using Technology (TUE): Time spent on technology or screens is often linked to sedentary behavior, which can contribute to obesity.
#
# •	Transportation Mode (MTRANS): The mode of transportation, such as walking or using public transportation, reflects levels of physical activity in daily life.
#
# •	Outcome variable (NOBeyesdad): Insufficient Weight, Normal Weight, Overweight Level I, Overweight Level II, Obesity Type I, Obesity Type II and Obesity Type III.

# %% [markdown]
# ### Import required packages and dataset

# %%
# Import required packages

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
# Import data

data = pd.read_csv(r"C:\Users\arezo\DSI_Assignments\Team Project\Estimation-of-Obesity-Levels\data\ObesityDataSet_raw_and_data_sinthetic.csv")

# %% [markdown]
# ### Display basic information about the dataset

# %%
data.head()
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0  Female  21.0    1.62    64.0                            yes   no   2.0
# 1  Female  21.0    1.52    56.0                            yes   no   3.0
# 2    Male  23.0    1.80    77.0                            yes   no   2.0
# 3    Male  27.0    1.80    87.0                             no   no   3.0
# 4    Male  22.0    1.78    89.8                             no   no   2.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
# 0  3.0  Sometimes    no   2.0   no  0.0  1.0          no
# 1  3.0  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes
# 2  3.0  Sometimes    no   2.0   no  2.0  1.0  Frequently
# 3  3.0  Sometimes    no   2.0   no  2.0  0.0  Frequently
# 4  1.0  Sometimes    no   2.0   no  0.0  0.0   Sometimes
#
#                   MTRANS           NObeyesdad
# 0  Public_Transportation        Normal_Weight
# 1  Public_Transportation        Normal_Weight
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          2111 non-null   object
#  1   Age                             2111 non-null   float64
#  2   Height                          2111 non-null   float64
#  3   Weight                          2111 non-null   float64
#  4   family_history_with_overweight  2111 non-null   object
#  5   FAVC                            2111 non-null   object
#  6   FCVC                            2111 non-null   float64
#  7   NCP                             2111 non-null   float64
#  8   CAEC                            2111 non-null   object
#  9   SMOKE                           2111 non-null   object
#  10  CH2O                            2111 non-null   float64
#  11  SCC                             2111 non-null   object
# ...

# %%
data.describe()
# Out:
#                Age       Height       Weight         FCVC          NCP  \
# count  2111.000000  2111.000000  2111.000000  2111.000000  2111.000000
# mean     24.312600     1.701677    86.586058     2.419043     2.685628
# std       6.345968     0.093305    26.191172     0.533927     0.778039
# min      14.000000     1.450000    39.000000     1.000000     1.000000
# 25%      19.947192     1.630000    65.473343     2.000000     2.658738
# 50%      22.777890     1.700499    83.000000     2.385502     3.000000
# 75%      26.000000     1.768464   107.430682     3.000000     3.000000
# max      61.000000     1.980000   173.000000     3.000000     4.000000
#
#               CH2O          FAF          TUE
# count  2111.000000  2111.000000  2111.000000
# mean      2.008011     1.010298     0.657866
# std       0.612953     0.850592     0.608927
# min       1.000000     0.000000     0.000000
# 25%       1.584812     0.124505     0.000000
# 50%       2.000000     1.000000     0.625350
# ...

# %% [markdown]
# ### Missing Values

# %%
# Find missing values

data.isna().sum()
# Out:
# Gender                            0
# Age                               0
# Height                            0
# Weight                            0
# family_history_with_overweight    0
# FAVC                              0
# FCVC                              0
# NCP                               0
# CAEC                              0
# SMOKE                             0
# CH2O                              0
# SCC                               0
# FAF                               0
# TUE                               0
# CALC                              0
# MTRANS                            0
# NObeyesdad                        0
# dtype: int64

# %% [markdown]
# No missing values was found in the dataset.

# %% [markdown]
# ### Duplicated Values

# %%
# Find duplicated values

data.duplicated().sum()
# Out:
# 24

# %%
# Show duplicated values

data[data.duplicated(keep=False)]
# Out:
#      Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 97   Female  21.0    1.52    42.0                             no   no   3.0
# 98   Female  21.0    1.52    42.0                             no   no   3.0
# 105  Female  25.0    1.57    55.0                             no  yes   2.0
# 106  Female  25.0    1.57    55.0                             no  yes   2.0
# 145    Male  21.0    1.62    70.0                             no  yes   2.0
# 174    Male  21.0    1.62    70.0                             no  yes   2.0
# 179    Male  21.0    1.62    70.0                             no  yes   2.0
# 184    Male  21.0    1.62    70.0                             no  yes   2.0
# 208  Female  22.0    1.69    65.0                            yes  yes   2.0
# 209  Female  22.0    1.69    65.0                            yes  yes   2.0
# 282  Female  18.0    1.62    55.0                            yes  yes   2.0
# ...

# %%
# Remove duplicated values

data = data.drop_duplicates()
data
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 0     Female  21.000000  1.620000   64.000000                            yes
# 1     Female  21.000000  1.520000   56.000000                            yes
# 2       Male  23.000000  1.800000   77.000000                            yes
# 3       Male  27.000000  1.800000   87.000000                             no
# 4       Male  22.000000  1.780000   89.800000                             no
# ...      ...        ...       ...         ...                            ...
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
# ...

# %% [markdown]
# ### Outliers

# %%
outlier_investigation = data.describe()
outlier_columns = ["Age", "Height", "Weight", "FCVC", "NCP", "CH2O", "FAF", "TUE"]

# boxplot approach
for column in outlier_columns:
    
    lower_quartile = data[column].quantile(0.25)
    upper_quartile = data[column].quantile(0.75)
    iqr = upper_quartile - lower_quartile
    iqr_extended = iqr * 2
    min_border = lower_quartile - iqr_extended
    max_border = upper_quartile + iqr_extended
    
    outliers = data[(data[column] < min_border) | (data[column] > max_border)].index
    print(f"{len(outliers)} outliers detected in column {column}")
# Out:
# 102 outliers detected in column Age
# 0 outliers detected in column Height
# 0 outliers detected in column Weight
# 0 outliers detected in column FCVC
# 523 outliers detected in column NCP
# 0 outliers detected in column CH2O
# 0 outliers detected in column FAF
# 0 outliers detected in column TUE

# %% [markdown]
# NCP is number of meals consumed daily and its values are known to fall between 1 and 4. Therefpre, we can confidently conclude that there are no outliers in this variable.
#
# We will explore the Age variable in greater detail using a box plot in the data visualization section.

# %% [markdown]
# ### Data Visulaization

# %%
# Age distribution across different obesity levels (NObeyesdad)

plt.figure(figsize=(10,8))
sns.boxplot(x='NObeyesdad', y='Age', data=data, palette='Set3')
plt.title('Age Distribution across Obesity Levels (NObeyesdad)')
plt.xlabel('Obesity Level (NObeyesdad)')
plt.ylabel('Age')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\arezo\AppData\Local\Temp\ipykernel_31140\3166932079.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='NObeyesdad', y='Age', data=data, palette='Set3')

# %% [markdown]
# Age variable ranges between 14 and 61, and at this point, we have decided not to remove any data as outliers from the dataset.

# %%
# 1. Distribution of different target labels (NObeyesdad)

plt.figure(figsize=(10,8))
sns.countplot(x='NObeyesdad', data=data, palette='Set3')
plt.title('Distribution of Obesity Levels (NObeyesdad)')
plt.xlabel('Obesity Level')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\arezo\AppData\Local\Temp\ipykernel_31140\1443405350.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='NObeyesdad', data=data, palette='Set3')

# %%
# 1. Draw Pairplot to explore relationships between numerical variables

sns.pairplot(data[['Age', 'Height', 'Weight', 'FCVC', 'CH2O', 'FAF', 'NObeyesdad']], hue='NObeyesdad', palette='Set3')
plt.show()

# %%
# Heatmap to check the correlation between numerical data

data_numerical = data.loc[:, ["Age", "Height", "Weight", "FCVC", "NCP", "CH2O", "FAF", "TUE"]]
plt.figure(figsize=(10,8))
sns.heatmap(data_numerical.corr(), annot=True, cmap='YlGnBu')
# Out:
# <Axes: >

# %% [markdown]
# We noticed a relatively strong positive correlation between the Weight and Height. We will define a new variable (BMI = Weight/Height^2).

# %%
# Define new variable of BMI

data['BMI'] = data['Weight'] / (data['Height'] ** 2)

# %%
# BMI distribution across different obesity levels (NObeyesdad)

plt.figure(figsize=(10,8))
nobeyesdad_order = ['Insufficient_Weight', 'Normal_Weight', 'Overweight_Level_I','Overweight_Level_II','Obesity_Type_I', 'Obesity_Type_II', 'Obesity_Type_III']  # Adjust according to your dataset
sns.boxplot(x='NObeyesdad', y='BMI', data=data, palette='Set3', order=nobeyesdad_order)
plt.title('BMI Distribution across Obesity Levels (NObeyesdad)')
plt.xlabel('Obesity Level (NObeyesdad)')
plt.ylabel('BMI')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\arezo\AppData\Local\Temp\ipykernel_31140\3858388814.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='NObeyesdad', y='BMI', data=data, palette='Set3', order=nobeyesdad_order)

# %% [markdown]
# The box plot effectively illustrates how BMI increases progressively with the severity of obesity levels. The spread of the data becomes wider with higher obesity categories, indicating more variation in BMI as obesity severity increases. Conversely, the Normal Weight and Insufficient Weight categories show more tightly grouped BMI distributions.

# %%
# BMI distribution across different obesity levels (NObeyesdad)

plt.figure(figsize=(10,8))
sns.boxplot(x='Gender', y='BMI', data=data, palette='Set3')
plt.title('BMI Distribution by Gender')
plt.xlabel('Gender')
plt.ylabel('BMI')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\arezo\AppData\Local\Temp\ipykernel_31140\3428719455.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Gender', y='BMI', data=data, palette='Set3')

# %% [markdown]
# The plot shows that females, on average, tend to have a higher and more varied BMI compared to males. The broader spread of BMI values in females suggests more diversity in body composition within this group.

# %%
# BMI distribution by Age across different obesity levels (NObeyesdad)

plt.figure(figsize=(10,8))
sns.scatterplot(x='Age', y='BMI', data=data, hue='NObeyesdad', palette='Set3')

plt.title('BMI Distribution by Age')
plt.xlabel('Age')
plt.ylabel('BMI')
plt.tight_layout()
plt.show()

# %% [markdown]
# Obesity type III is more commonly observed in individuals under the age of 30.

# %%
# BMI distribution by Family History with Overweight across different obesity levels (NObeyesdad)

plt.figure(figsize=(10,8))

# Define the desired order of FAVC categories and NObeyesdad levels

family_history_with_overweight_order = ['yes', 'no']  

# Create the barplot with the specified order

sns.barplot(x='family_history_with_overweight', y='BMI', data=data, hue='NObeyesdad', 
            palette='Set3', order=family_history_with_overweight_order, hue_order=nobeyesdad_order)

plt.title('BMI Distribution by Family History with Overweight')
plt.xlabel('Family History with Overweight')
plt.ylabel('BMI')
plt.tight_layout()
plt.show()

# %% [markdown]
# No cases of obesity level III have been observed in individuals without a family history of overweight, suggesting that family history plays a significant role, at least in the development of obesity level III.

# %%
# BMI distribution by Frequent Consumption of High-Calorie Food (FAVC) across different obesity levels (NObeyesdad)

plt.figure(figsize=(10, 8))

# Define the desired order of FAVC categories and NObeyesdad levels

favc_order = ['yes', 'no']  

# Create the barplot with the specified order

sns.barplot(x='FAVC', y='BMI', data=data, hue='NObeyesdad', 
            palette='Set3', order=favc_order, hue_order=nobeyesdad_order)

plt.title('BMI Distribution by Frequent Consumption of High-Calorie Food (FAVC)')
plt.xlabel('Frequent Consumption of High-Calorie Food (FAVC)')
plt.ylabel('BMI')
plt.tight_layout()
plt.show()

# %% [markdown]
# There is only one case of Obesity Type III where frequent consumption of high-calorie food is not present, suggesting that frequent consumption of high-calorie food likely plays a key role in the development of Obesity Type III.
#
# For other types of obesity and normal weight individuals, the distribution of high-calorie food consumption appears to be similar across all levels.

# %%
# BMI distribution by Frequency of Consumption of Vegetables (FCVC) across different obesity levels (NObeyesdad)

plt.figure(figsize=(10,8))
sns.scatterplot(x='FCVC', y='BMI', data=data, hue='NObeyesdad', palette='Set3')

plt.title('BMI Distribution by Frequency of Consumption of Vegetables (FCVC)')
plt.xlabel('Frequency of Consumption of Vegetables (FCVC)')
plt.ylabel('BMI')
plt.tight_layout()
plt.show()

# %% [markdown]
# Individuals with Obesity Type III have the highest frequency of vegetable consumption.

# %%
# BMI distribution by Number of Meals (NCP) across different obesity levels (NObeyesdad)

plt.figure(figsize=(10,8))
sns.scatterplot(x='NCP', y='BMI', data=data, hue='NObeyesdad', palette='Set3')

plt.title('BMI Distribution by Number of Meals (NCP)')
plt.xlabel('Number of Meals (NCP)')
plt.ylabel('BMI')
plt.tight_layout()
plt.show()

# %%
# BMI distribution by Consumption of Food Between Meals (CAEC) across different obesity levels (NObeyesdad)

plt.figure(figsize=(10,8))
sns.barplot(x='CAEC', y='BMI', data=data, hue='NObeyesdad', hue_order=nobeyesdad_order, palette='Set3')

plt.title('BMI Distribution by Consumption of Food Between Meals (CAEC)')
plt.xlabel('Consumption of Food Between Meals (CAEC)')
plt.ylabel('BMI')
plt.tight_layout()
plt.show()

# %% [markdown]
# Individuals with Obesity Type III often consumed food between meals (CAEC) occasionally, with no cases observed among those who either never used or always used CAEC. This suggests that the CAEC pattern may play a significant role in the development of Obesity Type III.

# %%
# BMI distribution by Smoking Habit (SMOKE) across different obesity levels (NObeyesdad)

plt.figure(figsize=(10,8))

smoke_order = ['yes', 'no']  

sns.barplot(x='SMOKE', y='BMI', data=data, hue='NObeyesdad', order=smoke_order, hue_order=nobeyesdad_order, palette='Set3')

plt.title('BMI Distribution by Smoking Habit (SMOKE)')
plt.xlabel('Smoking Habit (SMOKE)')
plt.ylabel('BMI')
plt.tight_layout()
plt.show()

# %%
# Distribution of genders across the target variable (NObeyesdad)

plt.figure(figsize=(10,8))
sns.countplot(x='NObeyesdad', hue='Gender', data=data, palette='Set3', order=nobeyesdad_order)

plt.title('Gender Distribution across Various Obesity Levels (NObeyesdad)')
plt.xlabel('Obesity Level (NObeyesdad)')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Gender')
plt.tight_layout()
plt.show()

# %% [markdown]
# The data suggests that males tend to have a significantly higher occurrence of Obesity Type II, whereas females appear to be more susceptible to Obesity Type III.

# %%
from scipy.stats import chi2_contingency

# Function to calculate Cramér's V
def cramers_v(x, y):
    table = pd.crosstab(x, y)
    chi2 = chi2_contingency(table)[0]
    n = table.sum().sum()
    r, k = table.shape
    return np.sqrt(chi2 / (n * (min(r, k) - 1)))

# Create a DataFrame with pairwise Cramér's V for all categorical variables
def cramers_v_matrix(df, categorical_cols):
    n = len(categorical_cols)
    cramer_v_matrix = np.zeros((n, n))
    
    for i in range(n):
        for j in range(n):
            if i == j:
                cramer_v_matrix[i, j] = 1  # Perfect association with itself
            else:
                cramer_v_matrix[i, j] = cramers_v(df[categorical_cols[i]], df[categorical_cols[j]])
    
    return pd.DataFrame(cramer_v_matrix, index=categorical_cols, columns=categorical_cols)

# Example: assuming `df` is your DataFrame and you have categorical columns
categorical_columns = ['Gender', 'family_history_with_overweight', 'FAVC', 'CAEC', 'SMOKE', 'SCC', 'CALC', 'MTRANS', 'NObeyesdad']
cramers_v_df = cramers_v_matrix(data, categorical_columns)

# Plot heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(cramers_v_df, annot=True, cmap='YlGnBu', vmin=0, vmax=1)
plt.title('Cramér\'s V Heatmap of Categorical Variables')
plt.show()

# %% [markdown]
# I noticed:
#
# •	a relatively strong positive correlation between gender and obesity level (Nobeyesdad)
#
# •	a relatively strong positive correlation between family_history_with_overweight and obesity level (Nobeyesdad)
#
# •	a positive correlation between frequent consumption of high-calorie food (FAVC) and obesity level (Nobeyesdad)
#
# •	a positive correlation between consumption of food between meals (CAEC) and obesity level (Nobeyesdad)

# %%
# Distribution of family_history_with_overweight across the target variable (NObeyesdad)

plt.figure(figsize=(10,8))
sns.countplot(x='NObeyesdad', hue='family_history_with_overweight', data=data, palette='Set3', order=nobeyesdad_order)
plt.title('Family History with Overweight Distribution across Various Obesity Levels (NObeyesdad)')
plt.xlabel('Obesity Level (NObeyesdad)')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Family History with Overweight')
plt.tight_layout()
plt.show()

# %% [markdown]
# •	The majority of individuals with Obesity Types I, II, and III have a family history of overweight, as shown by the dominant presence of the "yes" category (in green).
#
# •	For individuals with Overweight Levels I and II, a significant portion also has a family history of overweight, although there is a noticeable group without such a history.
#
# •	Normal Weight and Insufficient Weight categories show a more balanced distribution, with a larger proportion of individuals without a family history of overweight compared to the obesity levels.
#
# This suggests that family history of overweight may have a correlation with higher obesity levels.

# %%
# Distribution of frequent consumption of high-calorie food (FAVC) across the target variable (NObeyesdad)

plt.figure(figsize=(10,8))
sns.countplot(x='NObeyesdad', hue='FAVC', data=data, palette='Set3', order=nobeyesdad_order)
plt.title('Frequent Consumption of High-calorie Food (FAVC) Distribution across Various Obesity Levels (NObeyesdad)')
plt.xlabel('Obesity Level (NObeyesdad)')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Frequent Consumption of High-calorie Food (FAVC)')
plt.tight_layout()
plt.show()

# %% [markdown]
# •	The vast majority of individuals across Overweight Level I, Overweight Level II, and all Obesity Types (I, II, III) report frequently consuming high-calorie foods (indicated by "yes" in yellow).
#
# •	Interestingly, for individuals with normal weight and insufficient weight, there is a larger proportion of those who do not frequently consume high-calorie foods, with normal weight individuals showing a near balance between "yes" and "no."
#
# This indicates that frequent consumption of high-calorie food is highly associated with higher obesity levels.

# %%
# Distribution of consumption of food between meals (CAEC) across the target variable (NObeyesdad)

plt.figure(figsize=(10,8))
sns.countplot(x='NObeyesdad', hue='CAEC', data=data, palette='Set3', order=nobeyesdad_order)
plt.title('Frequent Consumption of Food between Meals (CAEC) Distribution across Various Obesity Levels (NObeyesdad)')
plt.xlabel('Obesity Level (NObeyesdad)')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Frequent Consumption of Food between Meals (CAEC)')
plt.tight_layout()
plt.show()

# %% [markdown]
# •	The chart demonstrates that "Sometimes" consumption of food between meals (green bars) is strongly associated with higher obesity levels, as indicated by the high counts for Overweight Levels I & II and Obesity Types I, II, and III.
#
# •	Frequent consumption (yellow bars), on the other hand, does not increase with obesity levels, and is more prevalent in normal weight and insufficient weight individuals.
